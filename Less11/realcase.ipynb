# %%
path = "https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/realcase/dataset_costi.xlsx"

# %%
#!wget https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/realcase/dataset_costi.xlsx

#Target colonna "costi anno 2020"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.read_excel(path)
df
# Out:
#       index Ragione sociale  costi anno 2020       var1       var2  var3  \
# 0       101      company101        144205134  147823139  148193655     0
# 1       102      company102        140165127  147562322  163251010     0
# 2       103      company103        145190000  147562000  142652000     0
# 3       104      company104        112760368  147067625  140160124     0
# 4       105      company105        171980718  145273739  127413305     0
# ...     ...             ...              ...        ...        ...   ...
# 7919   8020     company8020            81879       n.d.       n.d.     0
# 7920   8021     company8021            80757       n.d.       n.d.     0
# 7921   8022     company8022            74478       n.d.       n.d.  7000
# 7922   8023     company8023                0       n.d.       n.d.     0
# 7923   8024     company8024                0       n.d.     169365     0
#
#       var4  var5      var6      var7  ... Numero CCIAA  Codice fiscale  \
# ...

# %%
df = df.fillna(0)

# %%
df = df.replace('n.d.',0)

# %%
for e in  range(0,170):
    if df[e].mean() == 0:
        df.drop(df[e])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ifoa\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\ifoa\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\ifoa\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7924 entries, 0 to 7923
# Columns: 171 entries, index to var159
# dtypes: int64(68), object(103)
# memory usage: 10.3+ MB

# %%
df.describe()
# Out:
#            index  costi anno 2020          var1          var2          var3  \
# count  7924.0000     7.924000e+03  7.924000e+03  7.924000e+03  7.924000e+03
# mean   4062.5000     7.293933e+06  7.031743e+06  6.629497e+06  2.409513e+03
# std    2287.6061     1.649737e+07  1.608359e+07  1.557146e+07  3.752355e+04
# min     101.0000     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2081.7500     4.918298e+05  3.995690e+05  3.007438e+05  0.000000e+00
# 50%    4062.5000     1.611384e+06  1.478972e+06  1.349412e+06  0.000000e+00
# 75%    6043.2500     5.822246e+06  5.462268e+06  5.175886e+06  0.000000e+00
# max    8024.0000     1.754113e+08  1.478231e+08  1.954054e+08  2.500000e+06
#
#                var4          var5          var6          var7          var8  \
# count  7.924000e+03  7.924000e+03  7.924000e+03  7.924000e+03  7.924000e+03
# mean   3.432613e+03  3.289122e+03  3.253841e+05  2.796709e+05  2.248427e+05
# ...

# %%
sns.jointplot(x="costi anno 2020", y="Ragione sociale", data=df, size=8, color='red');
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 sns.jointplot(x="costi anno 2020", y="Ragione sociale", data=df, size=8, color='red');
#
# File c:\Users\ifoa\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:2265, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2262         marginal_kws.setdefault("fill", True)
#    2264     marginal_kws.setdefault("color", color)
# -> 2265     grid.plot_marginals(marg_func, **marginal_kws)
#    2267 elif kind.startswith("hist"):
#    2268
#    2269     # TODO process pair parameters for bins, etc. and pass
#    2270     # to both joint and marginal plots
#    2272     joint_kws.setdefault("color", color)
#
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X = df.drop(['costi anno 2020'],axis = 1).drop(['Ragione sociale'],axis = 1)
y = df['costi anno 2020']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.3, 
                                                    random_state=667
                                                    )

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 2
#       1 model = LinearRegression()
# ----> 2 model.fit(X_train, y_train)
#
# File c:\Users\ifoa\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
#     656 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     657     X,
#     658     y,
#    (...)
#     661     sample_weight=sample_weight,
#     662 )
#
# ...
